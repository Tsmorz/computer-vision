# %% [markdown]
# # Structure from Motion

# %%
import numpy as np
from scipy import ndimage as nd
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
import glob

# %% [markdown]
# Load Images

# %%
image_list = []
for filename in glob.glob('hotel-images/*.png'):
    im=Image.open(filename)

    # convert to gray if rgb
    if len(np.shape(im))==3:
        im = np.sum(im, 2) / 3

    image_list.append(im)

plt.imshow(image_list[0],cmap='gray')

# %%
# Scale Images
def scaleImages(im_list): 
    im_list2 = []
    im_list4 = []
    im_list8 = []
    im_list16 = []

    r,c = im_list[0].size
    for i in range(len(image_list)):
        im = im_list[i].resize((int(r/2), int(c/2)))
        im_list2.append(im)

        im = im_list[i].resize((int(r/4), int(c/4)))
        im_list4.append(im)

        im = im_list[i].resize((int(r/8), int(c/8)))
        im_list8.append(im)

        im = im_list[i].resize((int(r/16), int(c/16)))
        im_list16.append(im)

    return im_list2, im_list4, im_list8, im_list16

# %%
# Show images
scaled = scaleImages(image_list)

plt.figure()
plt.imshow(image_list[0])
plt.figure()
plt.imshow(scaled[0][0])
plt.figure()
plt.imshow(scaled[1][0])
plt.figure()
plt.imshow(scaled[2][0])
plt.figure()
plt.imshow(scaled[3][0])

# %%
# Out:
# 2

# %% [markdown]
# Image Features

# %%
# SIFT (Scale Invarient Feature Tracking)

# %% [markdown]
# Feature Point Tracking

# %%
# KLT

# %% [markdown]
# Save to ASCII output PLY file

# %%
# File output
